# %% [markdown]
# <a href="https://colab.research.google.com/github/dkaratzas/DL2022-23/blob/main/Problems%206%20-%20Pretrained%20CNNs/P6_CNN_PretrainedModels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%206%20-%20Pretrained%20CNNs/P6_CNN_PretrainedModels.ipynb)

# %% [markdown]
# # CNN Transfer Learning

# %% [markdown]
# In this notebook we will learn how to finetune a modern
# CNN architecture from the [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html), which has been pretrained on the [Imagenet dataset](http://www.image-net.org/). The [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html) module implements lots of popular CNN models such as: AlexNet, VGG, ResNet, DenseNet, GoogLeNet, etc.
#
#
# *Credit: This notebook has been adapted from the official [PyTorch finetuning tutorial](https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html).*
#
# The Imagenet dataset has 1000 classes and millions of images. Training a ResNet-50 model on ImageNet-1k with a single GPU takes several days. The key idea of transfer learning is to reuse the knowledge learned in one task to solve a different task. Transfer learning is specially useful when we do not have lots of training data for the new task nad/or when we want to speed up the training of the new model.
#
# For the target task we will use the [hymenoptera_data dataset](https://download.pytorch.org/tutorial/hymenoptera_data.zip), which consists in only **two classes** ('ants' and 'bees') and only around **one hundred training examples** for each class.

# %% [markdown]
# <table>
#     <tr>
#         <td style="text-align:center">bee</td><td style="text-align:center">ant</td>
#     </tr>
#     <tr>
#         <td><img src="......"></td>
#         <td><img src="......"></td>
#     </tr>
# </table>

# %% [markdown]
# We will perform two types of transfer learning: finetuning and feature extraction. In **finetuning**, we start with a pretrained model and update *all* of the model’s parameters for a new task. In **feature extraction**,
# we start with a pretrained model and only update the final layer weights.
#
# In general both transfer learning methods follow the same few steps:
#
# -  Initialize the pretrained model
# -  Reshape the final layer(s) to have the same number of outputs as the number of classes in the new dataset
# -  Define for the optimization algorithm which parameters we want to update during training
# -  Run the training step

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Load the necessary libraries
#
# The following code imports the packages needed for this example.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  2.0.0+cu118
# Torchvision Version:  0.15.1+cu118

# %%
# If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

# use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Prepare the dataset
#
# The *hymenoptera_data* dataset is structured such that we can use the [`ImageFolder()`](https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder) dataset class. Below you can see how to use PyTorch to download a dataset archive, unzip it, and then use the `ImageFolder()` function to create subsets from each subfolder.
#
# Since we will be reusing a pretrained model we must initialize the data transforms as in the original model. See [here](https://pytorch.org/vision/0.8/models.html) for more details.

# %%
# download the dataset
url = 'https://download.pytorch.org/tutorial/hymenoptera_data.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/hymenoptera_data/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Downloading https://download.pytorch.org/tutorial/hymenoptera_data.zip to ./data/hymenoptera_data.zip
# 100%|██████████| 47286322/47286322 [00:01<00:00, 30647433.28it/s]
# Extracting ./data/hymenoptera_data.zip to ./data
# Initializing Datasets and Dataloaders...
# Done
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ### Visualize some images

# %%
import matplotlib.image as mpimg

# show some images
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    idx = np.random.randint(0,len(image_datasets['train'].samples))
    image = mpimg.imread(image_datasets['train'].samples[idx][0])
    plt.imshow(image)
    plt.axis('off');

# %% [markdown]
# Since we have very little training data it makes sense to use some data augmentation for training.
#
# <span style="color:blue">
#
# **Exercise 1**: Change the transforms in the code below in order to add some data augmentation to the training data. See if you can do a random crop instead of always cropping in the middle, and add horizontal flips. Then recreate the datasets and dataloaders.
#
# </span>

# %%
# CHANGE THE CODE BELOW

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.RandomCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Initializing Datasets and Dataloaders...
# Done

# %% [markdown]
# ## Define the training function
#
# The `train_model` function handles the training and validation of a given model. As input, it takes a PyTorch model, a dictionary of dataloaders, a loss function, an optimizer, and a specified number of epochs to train and validate for.
#
# Instead of defining different functions for tranining and validation, we have combined everything into a single one below.
#
# Note that we also have implemented early stopping - we keep track of the performance of our model on the validation set, and we keep a copy of the best model found using Python's `copy.deepcopy()` function. After training finishes, we copy the best weights from the saved model.

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss.item())

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).cpu().numpy()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %% [markdown]
# ## Initialize the ResNet model
#
# We will use the Resnet18 model (the smaller one), as our dataset is small and only has two classes. When we print the model, we see that the last layer is a fully connected layer as shown below:
#
#
#    `(fc): Linear(in_features=512, out_features=1000, bias=True)`

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model():
    # Resnet18  
    model = models.resnet18()
    
    input_size = 224

    return model, input_size



# Initialize the model
model, input_size = initialize_model()

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 2**: Modify the function `initialize_model` so that it takes the number of classes `num_classes` as an argument, and it reinitializes `model.fc` to be a Linear layer with 512 input features and `num_classes` output features. Then use the function to create a model with 2 output classes.
#
# </span>

# %%
# YOUR CODE HERE!

# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model(num_classes):
    # Resnet18  
    model = models.resnet18()
    model.fc = nn.Linear(512,num_classes)
    input_size = 224

    return model, input_size

num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Run Training and Validation Step
#
# Let's start by training the model from scratch. What do you think will happen?

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 0.9546 Acc: 0.4959
# val Loss: 1.3658 Acc: 0.5882
#
# Epoch 1/14
# ----------
# train Loss: 0.6600 Acc: 0.6148
# val Loss: 0.8403 Acc: 0.5425
#
# Epoch 2/14
# ----------
# train Loss: 0.6685 Acc: 0.6311
# val Loss: 0.5607 Acc: 0.7451
#
# Epoch 3/14
# ----------
# train Loss: 0.6951 Acc: 0.5820
# val Loss: 0.6691 Acc: 0.6078
#
# Epoch 4/14
# ----------
# train Loss: 0.6661 Acc: 0.6475
# val Loss: 0.8803 Acc: 0.6993
#
# Epoch 5/14
# ----------
# train Loss: 0.6982 Acc: 0.6270
# val Loss: 0.6761 Acc: 0.7059
#
# Epoch 6/14
# ----------
# train Loss: 0.6090 Acc: 0.6680
# val Loss: 0.7260 Acc: 0.6863
#
# Epoch 7/14
# ----------
# train Loss: 0.6545 Acc: 0.6189
# val Loss: 0.6107 Acc: 0.6667
#
# Epoch 8/14
# ----------
# train Loss: 0.5887 Acc: 0.6967
# val Loss: 0.6027 Acc: 0.7190
#
# Epoch 9/14
# ----------
# train Loss: 0.5647 Acc: 0.6885
# val Loss: 0.6572 Acc: 0.6471
#
# Epoch 10/14
# ----------
# train Loss: 0.6154 Acc: 0.6803
# val Loss: 0.6207 Acc: 0.6732
#
# Epoch 11/14
# ----------
# train Loss: 0.5730 Acc: 0.7295
# val Loss: 1.0247 Acc: 0.6797
#
# Epoch 12/14
# ----------
# train Loss: 0.6044 Acc: 0.6967
# val Loss: 0.5032 Acc: 0.7908
#
# Epoch 13/14
# ----------
# train Loss: 0.6073 Acc: 0.6721
# val Loss: 0.6684 Acc: 0.7255
#
# Epoch 14/14
# ----------
# train Loss: 0.5730 Acc: 0.6926
# val Loss: 0.7009 Acc: 0.6144
#
# Training complete in 1m 5s
# Best val Acc: 0.790850

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses["train"], label="training loss")
ax1.plot(losses["val"], label="validation loss")
ax1.legend()

ax2.plot(hist["train"],label="training accuracy")
ax2.plot(hist["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# Training from scratch with only 100 examples per class does not allow the network to perform very well in this task. It reaches at most 70% accuracy, and the loss seems not to descrease anymore.

# %% [markdown]
# ## Preparing the model for finetuning and feature extraction
#
# In order to finetune a model or use it for feature extraction, we need to first load the pretrained weights, and then to freeze the part of the model we do not want to change.
#
# In order to load the pretrained weights for the ResNet model we must change a bit more the function `initialize model`. One one hand, we need to load the weights of the pre-trained ResNet model, trained on ImageNet.
#
# Moreover, depending on whether we want to do finetuning (update all parameters of the model) or if we want to do feature extraction (update only the last fully connected layer), we must specify which parameter to update.
#
# The following function sets the `.requires_grad` attribute of all the parameters in the model to False. This way we are freezing the model, since the parameters with `.requires_grad=False` will not be updated during training.

# %%
def freeze_model(model):
    for param in model.parameters():
        param.requires_grad = False

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 3**: Modify the function `initialize_model` so that it takes an extra argument called `finetuning`. If this function is True, then all parameters of the model should be able to update. If it is false, this would mean that we want to do feature extraction, and all parameters of the model should be frozen except the last fully connected layer.
#
# In addition, look up the documentation of [`models.resnet18()`](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html) and initialise the models with the `DEFAULT` weights.
#
# Then create again your model,
#
# </span>

# %%
# YOUR CODE HERE
def initialize_model(num_classes, finetuning=True):
    # Resnet18  
    model = models.resnet18(weights= 'DEFAULT')
    input_size = 224

    if finetuning == False:
        freeze_model(model)
    model.fc = nn.Linear(512 ,num_classes)
    

    return model, input_size

num_classes = 2

# Initialize the model
model_features, input_size = initialize_model(num_classes, False)

# Print the model we just instantiated
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:02<00:00, 22.2MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Create the Optimizer
#
# The final step for finetuning and feature extracting is to create an optimizer that **only** updates the desired parameters. Recall that after loading the pretrained model, if `finetuning == False` (we want to do feature extraction instead) we manually set all of the parameters' `.requires_grad` attributes to False. But the parameters of the reinitialized layer that we add afterwards have `.requires_grad=True` by default. So *all parameters that have `.requires_grad=True` should be optimized*. Next, we make a list of such parameters and input this list to the Adam algorithm constructor.

# %%
# Gather the parameters to be optimized/updated in this run. If we are finetuning we will be updating all parameters. However, if we are 
# doing feature extract method, we will only update the parameters that we have just initialized, i.e. the parameters with requires_grad is True.

params_to_update = []
for name, param in model_features.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)


# Now give our optimiser the list of all the parameters that need to be optimized
optimizer_ft = optim.Adam(params_to_update, lr=0.001)

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 4**: Train the model with feature extraction for 15 epochs. This is, you must freeze all parameters except the last fully connected layer. Plot the train/val losses and accuracies.
#
# Do not overwrite the previous best model, losses and accuracies, keep the new ones in separate variables.
#
# </span>

# %%
# YOUR CODE HERE
 # Send the model to GPU
model_features = model_features.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15

optimizer_ft = optim.Adam(model_features.parameters(), lr=0.001)

# Train and evaluate
model_features, hist_features, losses_features = train_model(model_features, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 0.2198 Acc: 0.9139
# val Loss: 0.2312 Acc: 0.9020
#
# Epoch 1/14
# ----------
# train Loss: 0.2252 Acc: 0.9098
# val Loss: 0.2346 Acc: 0.9085
#
# Epoch 2/14
# ----------
# train Loss: 0.2355 Acc: 0.8893
# val Loss: 0.3150 Acc: 0.8693
#
# Epoch 3/14
# ----------
# train Loss: 0.1720 Acc: 0.9344
# val Loss: 0.2213 Acc: 0.9150
#
# Epoch 4/14
# ----------
# train Loss: 0.1502 Acc: 0.9426
# val Loss: 0.2705 Acc: 0.8954
#
# Epoch 5/14
# ----------
# train Loss: 0.2631 Acc: 0.8811
# val Loss: 0.3323 Acc: 0.8693
#
# Epoch 6/14
# ----------
# train Loss: 0.2151 Acc: 0.8893
# val Loss: 0.2464 Acc: 0.9150
#
# Epoch 7/14
# ----------
# train Loss: 0.2369 Acc: 0.9098
# val Loss: 0.2196 Acc: 0.9150
#
# Epoch 8/14
# ----------
# train Loss: 0.1393 Acc: 0.9467
# val Loss: 0.2756 Acc: 0.8954
#
# Epoch 9/14
# ----------
# train Loss: 0.1622 Acc: 0.9303
# val Loss: 0.2214 Acc: 0.9216
#
# Epoch 10/14
# ----------
# train Loss: 0.1510 Acc: 0.9426
# val Loss: 0.1992 Acc: 0.9216
#
# Epoch 11/14
# ----------
# train Loss: 0.1758 Acc: 0.9303
# val Loss: 0.1963 Acc: 0.9281
#
# Epoch 12/14
# ----------
# train Loss: 0.1533 Acc: 0.9385
# val Loss: 0.2132 Acc: 0.9216
#
# Epoch 13/14
# ----------
# train Loss: 0.1409 Acc: 0.9426
# val Loss: 0.2927 Acc: 0.8824
#
# Epoch 14/14
# ----------
# train Loss: 0.1762 Acc: 0.9344
# val Loss: 0.2779 Acc: 0.8954
#
# Training complete in 0m 59s
# Best val Acc: 0.928105

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses_features["train"], label="training loss")
ax1.plot(losses_features["val"], label="validation loss")
ax1.legend()

ax2.plot(hist_features["train"],label="training accuracy")
ax2.plot(hist_features["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 5**: Now train the model finetuning all the parameters for 15 epochs. Plot the train/val losses and accuracies.
#
# Do not overwrite the previous best model, losses and accuracies, keep the new ones in separate variables.
#
# </span>

# %%
# YOUR CODE HERE
def initialize_model(num_classes, finetuning=True):
    # Resnet18  
    model = models.resnet18(weights= 'DEFAULT')
    input_size = 224

    if finetuning == False:
        freeze_model(model)
    model.fc = nn.Linear(512, num_classes)
    
    return model, input_size

num_classes = 2

# Initialize the model
model_finetuning, input_size = initialize_model(num_classes, True)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
params_to_update = []
for name, param in model_finetuning.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)


# Now give our optimiser the list of all the parameters that need to be optimized
optimizer_ft = optim.Adam(params_to_update, lr=0.001)

# %%
# YOUR CODE HERE

# Send the model to GPU
model_gpu = model_finetuning.to(device)

# Setup the loss function
loss_function = nn.CrossEntropyLoss()

# Number of epochs to train for
num_epochs = 15

optimizer = optim.Adam(model_gpu.parameters(), lr=0.001)

# Train and evaluate
model_finetuning, hist_finetuning, losses_finetuning = train_model(model_gpu, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 0.8958 Acc: 0.7049
# val Loss: 6.7541 Acc: 0.4379
#
# Epoch 1/14
# ----------
# train Loss: 0.5137 Acc: 0.7705
# val Loss: 0.9043 Acc: 0.6144
#
# Epoch 2/14
# ----------
# train Loss: 0.5640 Acc: 0.7008
# val Loss: 1.3085 Acc: 0.7255
#
# Epoch 3/14
# ----------
# train Loss: 0.5594 Acc: 0.7500
# val Loss: 0.6577 Acc: 0.6667
#
# Epoch 4/14
# ----------
# train Loss: 0.5207 Acc: 0.7377
# val Loss: 0.4880 Acc: 0.8235
#
# Epoch 5/14
# ----------
# train Loss: 0.4072 Acc: 0.8402
# val Loss: 0.6805 Acc: 0.6797
#
# Epoch 6/14
# ----------
# train Loss: 0.3359 Acc: 0.8975
# val Loss: 0.6450 Acc: 0.7647
#
# Epoch 7/14
# ----------
# train Loss: 0.4381 Acc: 0.8279
# val Loss: 0.6795 Acc: 0.7255
#
# Epoch 8/14
# ----------
# train Loss: 0.4590 Acc: 0.8238
# val Loss: 0.6469 Acc: 0.6601
#
# Epoch 9/14
# ----------
# train Loss: 0.3462 Acc: 0.9016
# val Loss: 0.4438 Acc: 0.8039
#
# Epoch 10/14
# ----------
# train Loss: 0.2871 Acc: 0.8893
# val Loss: 0.4146 Acc: 0.8431
#
# Epoch 11/14
# ----------
# train Loss: 0.1917 Acc: 0.9549
# val Loss: 0.4251 Acc: 0.8105
#
# Epoch 12/14
# ----------
# train Loss: 0.3755 Acc: 0.8525
# val Loss: 0.7664 Acc: 0.7647
#
# Epoch 13/14
# ----------
# train Loss: 0.2920 Acc: 0.8730
# val Loss: 0.3923 Acc: 0.8301
#
# Epoch 14/14
# ----------
# train Loss: 0.1927 Acc: 0.9262
# val Loss: 0.5740 Acc: 0.7974
#
# Training complete in 0m 60s
# Best val Acc: 0.843137

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses_finetuning["train"], label="training loss")
ax1.plot(losses_finetuning["val"], label="validation loss")
ax1.legend()

ax2.plot(hist_finetuning["train"],label="training accuracy")
ax2.plot(hist_finetuning["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 6**: Plot the  train/val losses and accuracies of all three approaches: training from scratch, finetunning, and festure extraction. To make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# Make the plot self-explanatory: use legends and titles for each subplot, and a main title for the whole figure.
#
# </span>

# %%
# YOUR CODE HERE
# plot the losses and accuracies
fig, ax= plt.subplots(3, 2, figsize=(16, 6))

ax[0,0].plot(losses["train"], label="training loss")
ax[0,0].plot(losses["val"], label="validation loss")
ax[0,0].legend()

ax[0,1].plot(hist["train"],label="training accuracy")
ax[0,1].plot(hist["val"],label="val accuracy")
ax[0,1].legend()

ax[1,0].plot(losses_features["train"], label="training loss with frozen params")
ax[1,0].plot(losses_features["val"], label="validation loss with frozen params")
ax[1,0].legend()

ax[1,1].plot(hist_features["train"],label="training accuracy")
ax[1,1].plot(hist_features["val"],label="val accuracy")
ax[1,1].legend()

ax[2,0].plot(losses_finetuning["train"], label="training loss with learned params")
ax[2,0].plot(losses_finetuning["val"], label="validation loss with learned params")
ax[2,0].legend()

ax[2,1].plot(hist_finetuning["train"],label="training accuracy")
ax[2,1].plot(hist_finetuning["val"],label="val accuracy")
ax[2,1].legend()

plt.show()

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 7**: Train the ResNet-18 model for a different dataset (MIT Scenes) using the three training strategies: from scratch (do not load pre-trained weights), finetunning, and feature extraction. Train the model **for 40 epochs** - each training process should take approx. 10 minutes on colab.
#
# The URL of the dataset is the following (you also have the file on Campus Virtual):
#
# http://wwwo.cvc.uab.es/people/dimos/downloads/MIT_scenes.zip
#
# The dataset contains scene images of **8 classes**: coast, forest, highway, inside_city, mountain, open_country, street, and tallbuilding. The number of training images per class varies between 187 and 295.
#
# Train the three models and plot the  train/val losses and accuracies of all of them. Again, to make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# </span>

# %%
# YOUR CODE HERE!
# download the dataset
url = 'http://wwwo.cvc.uab.es/people/dimos/downloads/MIT_scenes.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/hymenoptera_data/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Downloading http://wwwo.cvc.uab.es/people/dimos/downloads/MIT_scenes.zip to ./data/MIT_scenes.zip
# 100%|██████████| 127093454/127093454 [01:18<00:00, 1613789.13it/s]
# Extracting ./data/MIT_scenes.zip to ./data
# Initializing Datasets and Dataloaders...
# Done

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss.item())

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).cpu().numpy()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model(num_c):
    # Resnet18  
    model = models.resnet18()
    model.fc = nn.Linear(512,num_c)
    input_size = 224

    return model, input_size

num_c=8

# Initialize the model
model, input_size = initialize_model(num_c)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=8, bias=True)
# )

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# train Loss: 0.9838 Acc: 0.5533
# val Loss: 3.2403 Acc: 0.5556
#
# Epoch 1/39
# ----------
# train Loss: 0.7388 Acc: 0.5369
# val Loss: 0.6441 Acc: 0.6340
#
# Epoch 2/39
# ----------
# train Loss: 0.6978 Acc: 0.6025
# val Loss: 0.9185 Acc: 0.6340
#
# Epoch 3/39
# ----------
# train Loss: 0.6772 Acc: 0.6189
# val Loss: 0.9059 Acc: 0.5817
#
# Epoch 4/39
# ----------
# train Loss: 0.6976 Acc: 0.5697
# val Loss: 0.6726 Acc: 0.6144
#
# Epoch 5/39
# ----------
# train Loss: 0.6565 Acc: 0.6393
# val Loss: 0.5970 Acc: 0.7190
#
# Epoch 6/39
# ----------
# train Loss: 0.6396 Acc: 0.6598
# val Loss: 0.6357 Acc: 0.6601
#
# Epoch 7/39
# ----------
# train Loss: 0.6171 Acc: 0.6475
# val Loss: 0.7734 Acc: 0.5752
#
# Epoch 8/39
# ----------
# train Loss: 0.6132 Acc: 0.6393
# val Loss: 0.6015 Acc: 0.6928
#
# Epoch 9/39
# ----------
# train Loss: 0.6160 Acc: 0.6557
# val Loss: 0.7154 Acc: 0.6732
#
# Epoch 10/39
# ----------
# train Loss: 0.6743 Acc: 0.6393
# val Loss: 0.6359 Acc: 0.7059
#
# Epoch 11/39
# ----------
# train Loss: 0.6329 Acc: 0.6393
# val Loss: 0.5969 Acc: 0.6928
#
# Epoch 12/39
# ----------
# train Loss: 0.6301 Acc: 0.6311
# val Loss: 0.7114 Acc: 0.5882
#
# Epoch 13/39
# ----------
# train Loss: 0.6274 Acc: 0.6516
# val Loss: 0.7210 Acc: 0.6340
#
# Epoch 14/39
# ----------
# train Loss: 0.6017 Acc: 0.6762
# val Loss: 0.6222 Acc: 0.7320
#
# Epoch 15/39
# ----------
# train Loss: 0.6289 Acc: 0.6639
# val Loss: 0.7699 Acc: 0.6013
#
# Epoch 16/39
# ----------
# train Loss: 0.6006 Acc: 0.6926
# val Loss: 0.6178 Acc: 0.6797
#
# Epoch 17/39
# ----------
# train Loss: 0.6062 Acc: 0.6598
# val Loss: 0.6229 Acc: 0.6993
#
# Epoch 18/39
# ----------
# train Loss: 0.5871 Acc: 0.6844
# val Loss: 0.5315 Acc: 0.7386
#
# Epoch 19/39
# ----------
# train Loss: 0.5767 Acc: 0.6762
# val Loss: 0.4973 Acc: 0.7843
#
# Epoch 20/39
# ----------
# train Loss: 0.5606 Acc: 0.7008
# val Loss: 0.9543 Acc: 0.6209
#
# Epoch 21/39
# ----------
# train Loss: 0.5743 Acc: 0.7213
# val Loss: 0.5764 Acc: 0.6993
#
# Epoch 22/39
# ----------
# train Loss: 0.5762 Acc: 0.7008
# val Loss: 0.6549 Acc: 0.6993
#
# Epoch 23/39
# ----------
# train Loss: 0.5876 Acc: 0.6967
# val Loss: 0.6337 Acc: 0.7190
#
# Epoch 24/39
# ----------
# train Loss: 0.5564 Acc: 0.7172
# val Loss: 0.5161 Acc: 0.7451
#
# Epoch 25/39
# ----------
# train Loss: 0.5678 Acc: 0.7172
# val Loss: 0.5017 Acc: 0.7843
#
# Epoch 26/39
# ----------
# train Loss: 0.4995 Acc: 0.7623
# val Loss: 0.7550 Acc: 0.6471
#
# Epoch 27/39
# ----------
# train Loss: 0.6001 Acc: 0.6803
# val Loss: 0.6698 Acc: 0.6405
#
# Epoch 28/39
# ----------
# train Loss: 0.4928 Acc: 0.7746
# val Loss: 0.7049 Acc: 0.7059
#
# Epoch 29/39
# ----------
# train Loss: 0.4149 Acc: 0.8197
# val Loss: 0.8200 Acc: 0.7255
#
# Epoch 30/39
# ----------
# train Loss: 0.4428 Acc: 0.8033
# val Loss: 0.7952 Acc: 0.6863
#
# Epoch 31/39
# ----------
# train Loss: 0.5141 Acc: 0.7254
# val Loss: 0.5595 Acc: 0.7190
#
# Epoch 32/39
# ----------
# train Loss: 0.3716 Acc: 0.8361
# val Loss: 0.6478 Acc: 0.7124
#
# Epoch 33/39
# ----------
# train Loss: 0.4205 Acc: 0.8279
# val Loss: 0.8162 Acc: 0.6536
#
# Epoch 34/39
# ----------
# train Loss: 0.4264 Acc: 0.8115
# val Loss: 0.6964 Acc: 0.6471
#
# Epoch 35/39
# ----------
# train Loss: 0.3421 Acc: 0.8484
# val Loss: 0.7192 Acc: 0.7059
#
# Epoch 36/39
# ----------
# train Loss: 0.4154 Acc: 0.8033
# val Loss: 0.7442 Acc: 0.6993
#
# Epoch 37/39
# ----------
# train Loss: 0.3112 Acc: 0.8689
# val Loss: 0.7619 Acc: 0.6667
#
# Epoch 38/39
# ----------
# train Loss: 0.2728 Acc: 0.8607
# val Loss: 0.8235 Acc: 0.6013
#
# Epoch 39/39
# ----------
# train Loss: 0.3557 Acc: 0.8443
# val Loss: 0.7639 Acc: 0.6667
#
# Training complete in 2m 39s
# Best val Acc: 0.784314

# %%
# YOUR CODE HERE
def initialize_model(num_c, finetuning=True):
    # Resnet18  
    model = models.resnet18(weights= 'DEFAULT')
    input_size = 224

    if finetuning == False:
        freeze_model(model)
    model.fc = nn.Linear(512,num_c)
    

    return model, input_size

num_c=8

# Initialize the model
model_features, input_size = initialize_model(num_c,False)

# %%
# YOUR CODE HERE
 # Send the model to GPU
model_features = model_features.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model_features.parameters(), lr=0.001)

# Train and evaluate
model_features, hist_features, losses_features = train_model(model_features, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# train Loss: 0.8207 Acc: 0.5533
# val Loss: 0.4499 Acc: 0.8431
#
# Epoch 1/39
# ----------
# train Loss: 0.4362 Acc: 0.8156
# val Loss: 0.3296 Acc: 0.8693
#
# Epoch 2/39
# ----------
# train Loss: 0.3634 Acc: 0.8607
# val Loss: 0.2858 Acc: 0.8954
#
# Epoch 3/39
# ----------
# train Loss: 0.3029 Acc: 0.8607
# val Loss: 0.2948 Acc: 0.8954
#
# Epoch 4/39
# ----------
# train Loss: 0.2434 Acc: 0.9221
# val Loss: 0.2381 Acc: 0.9020
#
# Epoch 5/39
# ----------
# train Loss: 0.2573 Acc: 0.8934
# val Loss: 0.2411 Acc: 0.9020
#
# Epoch 6/39
# ----------
# train Loss: 0.1867 Acc: 0.9385
# val Loss: 0.2522 Acc: 0.9085
#
# Epoch 7/39
# ----------
# train Loss: 0.2498 Acc: 0.9057
# val Loss: 0.2486 Acc: 0.9085
#
# Epoch 8/39
# ----------
# train Loss: 0.2316 Acc: 0.8934
# val Loss: 0.2213 Acc: 0.9085
#
# Epoch 9/39
# ----------
# train Loss: 0.2315 Acc: 0.9139
# val Loss: 0.2238 Acc: 0.9020
#
# Epoch 10/39
# ----------
# train Loss: 0.1625 Acc: 0.9426
# val Loss: 0.2279 Acc: 0.9020
#
# Epoch 11/39
# ----------
# train Loss: 0.1501 Acc: 0.9467
# val Loss: 0.2124 Acc: 0.9216
#
# Epoch 12/39
# ----------
# train Loss: 0.1532 Acc: 0.9508
# val Loss: 0.2140 Acc: 0.9020
#
# Epoch 13/39
# ----------
# train Loss: 0.2000 Acc: 0.9180
# val Loss: 0.2199 Acc: 0.9020
#
# Epoch 14/39
# ----------
# train Loss: 0.1452 Acc: 0.9508
# val Loss: 0.2476 Acc: 0.8889
#
# Epoch 15/39
# ----------
# train Loss: 0.1665 Acc: 0.9180
# val Loss: 0.2084 Acc: 0.9281
#
# Epoch 16/39
# ----------
# train Loss: 0.1774 Acc: 0.9262
# val Loss: 0.2365 Acc: 0.8954
#
# Epoch 17/39
# ----------
# train Loss: 0.1690 Acc: 0.9344
# val Loss: 0.2250 Acc: 0.9020
#
# Epoch 18/39
# ----------
# train Loss: 0.1630 Acc: 0.9262
# val Loss: 0.2444 Acc: 0.8889
#
# Epoch 19/39
# ----------
# train Loss: 0.1783 Acc: 0.9344
# val Loss: 0.2141 Acc: 0.9216
#
# Epoch 20/39
# ----------
# train Loss: 0.1674 Acc: 0.9180
# val Loss: 0.2262 Acc: 0.8954
#
# Epoch 21/39
# ----------
# train Loss: 0.1698 Acc: 0.9344
# val Loss: 0.2979 Acc: 0.8758
#
# Epoch 22/39
# ----------
# train Loss: 0.1868 Acc: 0.9180
# val Loss: 0.2730 Acc: 0.8889
#
# Epoch 23/39
# ----------
# train Loss: 0.1604 Acc: 0.9385
# val Loss: 0.2904 Acc: 0.8824
#
# Epoch 24/39
# ----------
# train Loss: 0.1507 Acc: 0.9426
# val Loss: 0.2735 Acc: 0.8889
#
# Epoch 25/39
# ----------
# train Loss: 0.1377 Acc: 0.9508
# val Loss: 0.2139 Acc: 0.9150
#
# Epoch 26/39
# ----------
# train Loss: 0.2142 Acc: 0.9016
# val Loss: 0.2322 Acc: 0.8954
#
# Epoch 27/39
# ----------
# train Loss: 0.1693 Acc: 0.9344
# val Loss: 0.2274 Acc: 0.9020
#
# Epoch 28/39
# ----------
# train Loss: 0.1766 Acc: 0.9139
# val Loss: 0.2502 Acc: 0.8889
#
# Epoch 29/39
# ----------
# train Loss: 0.2095 Acc: 0.8975
# val Loss: 0.2148 Acc: 0.9150
#
# Epoch 30/39
# ----------
# train Loss: 0.1747 Acc: 0.9303
# val Loss: 0.2687 Acc: 0.8889
#
# Epoch 31/39
# ----------
# train Loss: 0.1404 Acc: 0.9385
# val Loss: 0.2372 Acc: 0.8954
#
# Epoch 32/39
# ----------
# train Loss: 0.1373 Acc: 0.9508
# val Loss: 0.2871 Acc: 0.8824
#
# Epoch 33/39
# ----------
# train Loss: 0.1912 Acc: 0.9180
# val Loss: 0.3028 Acc: 0.8824
#
# Epoch 34/39
# ----------
# train Loss: 0.1312 Acc: 0.9426
# val Loss: 0.2005 Acc: 0.9346
#
# Epoch 35/39
# ----------
# train Loss: 0.1508 Acc: 0.9221
# val Loss: 0.2305 Acc: 0.9150
#
# Epoch 36/39
# ----------
# train Loss: 0.1487 Acc: 0.9385
# val Loss: 0.2423 Acc: 0.9020
#
# Epoch 37/39
# ----------
# train Loss: 0.1160 Acc: 0.9508
# val Loss: 0.2113 Acc: 0.9216
#
# Epoch 38/39
# ----------
# train Loss: 0.0799 Acc: 0.9836
# val Loss: 0.2136 Acc: 0.9216
#
# Epoch 39/39
# ----------
# train Loss: 0.2423 Acc: 0.9098
# val Loss: 0.2144 Acc: 0.9216
#
# Training complete in 2m 29s
# Best val Acc: 0.934641

# %%
# YOUR CODE HERE
def initialize_model(num_c, finetuning=True):
    # Resnet18  
    model = models.resnet18(weights= 'DEFAULT')
    input_size = 224

    if finetuning == False:
        freeze_model(model)
    model.fc = nn.Linear(512,num_c)
    

    return model, input_size

num_c = 8

# Initialize the model
model_finetuning, input_size = initialize_model(num_c,True)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=8, bias=True)
# )

# %%
# YOUR CODE HERE
# Send the model to GPU
model_finetuning = model_finetuning.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model_finetuning.parameters(), lr=0.001)

# Train and evaluate
model_finetuning, hist_finetuning, losses_finetuning = train_model(model_finetuning, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# train Loss: 1.1394 Acc: 0.6025
# val Loss: 0.7519 Acc: 0.6601
#
# Epoch 1/39
# ----------
# train Loss: 0.6547 Acc: 0.6557
# val Loss: 0.8129 Acc: 0.6144
#
# Epoch 2/39
# ----------
# train Loss: 0.6199 Acc: 0.6680
# val Loss: 0.6866 Acc: 0.7386
#
# Epoch 3/39
# ----------
# train Loss: 0.5819 Acc: 0.7541
# val Loss: 0.6508 Acc: 0.6993
#
# Epoch 4/39
# ----------
# train Loss: 0.6492 Acc: 0.6639
# val Loss: 0.6500 Acc: 0.7386
#
# Epoch 5/39
# ----------
# train Loss: 0.5149 Acc: 0.7828
# val Loss: 1.7890 Acc: 0.5229
#
# Epoch 6/39
# ----------
# train Loss: 0.5656 Acc: 0.7008
# val Loss: 0.5855 Acc: 0.7843
#
# Epoch 7/39
# ----------
# train Loss: 0.4230 Acc: 0.8279
# val Loss: 0.5940 Acc: 0.6993
#
# Epoch 8/39
# ----------
# train Loss: 0.4331 Acc: 0.8074
# val Loss: 0.8381 Acc: 0.7516
#
# Epoch 9/39
# ----------
# train Loss: 0.4207 Acc: 0.8279
# val Loss: 1.4872 Acc: 0.5948
#
# Epoch 10/39
# ----------
# train Loss: 0.4440 Acc: 0.7869
# val Loss: 0.6744 Acc: 0.7516
#
# Epoch 11/39
# ----------
# train Loss: 0.2618 Acc: 0.8893
# val Loss: 0.9188 Acc: 0.7582
#
# Epoch 12/39
# ----------
# train Loss: 0.2476 Acc: 0.9180
# val Loss: 0.9531 Acc: 0.6993
#
# Epoch 13/39
# ----------
# train Loss: 0.4203 Acc: 0.8279
# val Loss: 0.8863 Acc: 0.6405
#
# Epoch 14/39
# ----------
# train Loss: 0.2442 Acc: 0.9180
# val Loss: 0.3958 Acc: 0.8301
#
# Epoch 15/39
# ----------
# train Loss: 0.3847 Acc: 0.8689
# val Loss: 0.5365 Acc: 0.8431
#
# Epoch 16/39
# ----------
# train Loss: 0.2567 Acc: 0.8975
# val Loss: 0.7318 Acc: 0.7778
#
# Epoch 17/39
# ----------
# train Loss: 0.2500 Acc: 0.9180
# val Loss: 0.5471 Acc: 0.7778
#
# Epoch 18/39
# ----------
# train Loss: 0.2657 Acc: 0.8934
# val Loss: 0.5143 Acc: 0.8301
#
# Epoch 19/39
# ----------
# train Loss: 0.2456 Acc: 0.8852
# val Loss: 1.0655 Acc: 0.6340
#
# Epoch 20/39
# ----------
# train Loss: 0.2002 Acc: 0.9057
# val Loss: 0.4387 Acc: 0.7843
#
# Epoch 21/39
# ----------
# train Loss: 0.1562 Acc: 0.9590

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 7**: Visualize some of the images along with the classification results of your best model.
#
# *Hints: (1) The images that the dataloader gives you are already normalised, you need to "de-normalise" them if you want to see the true colours. (2) The order of dimensions of PyTorch is C, H, W, if you want to plot images you need your arrays ordered as H, W, C.*
#
# </span>

# %%
# YOUR CODE HERE!
